# %% [markdown]
# <a href="https://colab.research.google.com/github/ayuannisa17/PCdVK_ganjil_2026/blob/main/Pertemuan_2b.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# pengenalan phyton

# %%
import cv2 as cv
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from google.colab.patches import cv2_imshow
from PIL import Image
from skimage import io, transform

# 1. Menyiapkan list URL
urls = [
    "https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg",
    "https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg",
    "https://unair.ac.id/wp-content/uploads/2020/12/Kucing.jpg",
]

# 2. Loop untuk baca dan tampilkan setiap gambar
for url in urls:
    image = io.imread(url)  # read image

    # Normalisasi channel (RGBA/RGB ke BGR)
    if image.ndim == 3 and image.shape[2] == 4:
        image = cv.cvtColor(image, cv.COLOR_RGBA2BGR)
    elif image.ndim == 3 and image.shape[2] == 3:
        image = cv.cvtColor(image, cv.COLOR_RGB2BGR)

    image = cv.resize(image, (0, 0), fx=0.5, fy=0.5)  # resize setengah ukuran
    image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)  # konversi ke RGB
    final_frame = cv.hconcat((image, image_2))  # gabung kiri-kanan

    cv2_imshow(final_frame)  # tampilkan
    print("\n")
# Out:
# <PIL.Image.Image image mode=RGB size=800x276>
# <PIL.Image.Image image mode=RGB size=800x286>
# <PIL.Image.Image image mode=RGB size=750x250>

# %%
tinggi = image_2.shape[0]
lebar = image_2.shape[1]

print("resolusi image: tinggi x lebar = ", tinggi, " x ", lebar)
cv2_imshow(image_2)
# Out:
# resolusi image: tinggi x lebar =  250  x  375
# <PIL.Image.Image image mode=RGB size=375x250>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

#membuat garis horizontal ditengah image
for y in range (lebar):
  image_3[int((tinggi)/2),y] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=750x250>

# %% [markdown]
# pertanyaan praktikum D2

# %% [markdown]
# 1. Jelaskan, mengapa pada modul praktikum ini eksekusi kode Python dilakukan
# menggunakan Google Colab?
# - karena gratis, tidak perlu instalasi, menyediakan akses GPU/TPU, dapat diakses dari browser, dan tersimpan di cloud sehingga memudahkan kolaborasi serta akses di mana saja
#
# 2. Jelaskan mengenai kegunaan setiap library pada praktikum langkah ke
# delapan? Apakah semua library tersebut harus digunakan dalam praktikum
# sesi ini?
# - NumPy untuk manipulasi array, Pandas untuk analisis data, CV2/OpenCV untuk pengolahan citra dan visi komputer, Skimage untuk pemrosesan citra lanjutan, Matplotlib untuk visualisasi dan plotting gambar, serta PIL untuk membuka dan menyimpan gambar. Tidak semua library harus digunakan, hanya yang dibutuhkan saja yang dipakai dalam praktikum
#
# 3. Pada uji coba langkah ke-9 terdapat potongan kode program sebagai berikut :
# image = cv.resize(image, (0,0), fx=0.5, fy=0.5)
# Apa kegunaan kode program tersebut?dan apa pengaruhnya jika tidak
# dilakukan?
# - berfungsi untuk mengecilkan ukuran gambar menjadi setengah dari ukuran asli. Jika tidak dilakukan, gambar akan tetap dalam ukuran asli sehingga tampil lebih besar
#
# 4. perhatikan potongan kode program berikut:
# #membuat garis horizonal ditengah image
# for y in range (lebar):
#   image_3[int((tinggi)/2),y] = [255,255,255]
#
# Apa kegunaan kode [255,255,255]? jelaskan?
# - kode tersebut digunakan untuk merepresentasikan warna putih dalam format BGR atau RGB pada citra digital
#
# 5. Jelaskan keterkaitan antara pixel dan juga resolusi gambar yang tinggi ataupun
# rendah!
# - esolusi menentukan jumlah pixel pada gambar. Semakin tinggi resolusi, semakin banyak pixel yang tersusun sehingga detail gambar lebih tajam dan jelas. Sebaliknya, resolusi rendah berarti pixel lebih sedikit sehingga detail gambar menjadi kasar atau kurang jelas

# %% [markdown]
# Tugas praktikum D2

# %%
# 2. Buat garis vertikal dan garis menyilang diagonal pada image keluaran
image_vertikal = image_rgb.copy()
for x in range(tinggi):
    image_vertikal[x, int(lebar/2)] = [255, 255, 255]

vertikal_before_after = cv.hconcat((image_rgb, image_vertikal))
cv2_imshow(vertikal_before_after)

image_diagonal = image_rgb.copy()
cv.line(image_diagonal, (0, 0), (lebar-1, tinggi-1), [255, 255, 255], 2)
cv.line(image_diagonal, (lebar-1, 0), (0, tinggi-1), [255, 255, 255], 2)

cv2_imshow(image_diagonal)
# Out:
# <PIL.Image.Image image mode=RGB size=750x250>
# <PIL.Image.Image image mode=RGB size=375x250>

# %%
# 3. Buat garis horisontal berwarna putih dibagian tengah gambar dengan panjang tertentu
image_horizontal = image_rgb.copy()
titik_tengah_y = int(tinggi / 2)
titik_tengah_x = int(lebar / 2)
panjang = 100
cv.line(image_horizontal, (titik_tengah_x - int(panjang/2), titik_tengah_y), (titik_tengah_x + int(panjang/2), titik_tengah_y), [255, 255, 255], 2)
cv2_imshow(image_horizontal)
# Out:
# <PIL.Image.Image image mode=RGB size=375x250>

# %%
# 4. Buat kotak menggunakan kumpulan pixel warna putih di sembarang tempat dalam gambar
image_kotak = image_rgb.copy()
y1 = int(tinggi / 2) - 25
y2 = int(tinggi / 2) + 25
x1 = int(lebar / 2) - 25
x2 = int(lebar / 2) + 25
image_kotak[y1:y2, x1:x2] = [255, 255, 255]
cv2_imshow(image_kotak)
# Out:
# <PIL.Image.Image image mode=RGB size=375x250>

# %% [markdown]
# D3. Pengenalan Python

# %%
#1
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-2d9cb55b-9186-4fc7-a255-7cbfa0cb54c9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2d9cb55b-9186-4fc7-a255-7cbfa0cb54c9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import cv2
from google.colab.patches import cv2_imshow

img = cv2.imread('Cuplikan layar 2026-09-04 184341.png')
cv2_imshow(img)

print('Resolusi gambar:', img.shape[1], "x", img.shape[0])
# Out:
# <PIL.Image.Image image mode=RGB size=497x310>
# Resolusi gambar: 497 x 310

# %%
#2 menampilkan gambar

import cv2
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow

img = cv2.imread("/content/drive/MyDrive/PCdVK/Cuplikan layar 2026-09-04 184341.png")
plt.imshow(img)
plt.show()

# %%
img = cv2.imread("/content/drive/MyDrive/PCdVK/Cuplikan layar 2026-09-04 184341.png")
img2 = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img2)
plt.show()

# %%
img = cv2.imread("/content/drive/MyDrive/PCdVK/Cuplikan layar 2026-09-04 184341.png")
img2 = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img2)
plt.show()

# %%
# 3. Menampilkan citra Grayscale
img_gray = cv2.imread("/content/drive/MyDrive/PCdVK/Cuplikan layar 2026-09-04 184341.png", cv2.IMREAD_GRAYSCALE)

# Tanpa cmap
plt.subplot(1,2,1)
plt.imshow(img_gray)
plt.title("Tanpa cmap")

#  Dengan cmap
plt.subplot(1,2,2)
plt.imshow(img_gray, cmap="gray")
plt.title("Dengan cmap")

plt.show()

# %%
plt.imshow(img_gray, cmap="magma")
plt.show()

# %%
# 4. melakukan resizing

img = cv2.imread("/content/drive/MyDrive/PCdVK/Cuplikan layar 2026-09-04 184341.png")
imgRGB=cv2.cvtColor(img, cv2.COLOR_BGR2RGB) #Konversi BGR ke RGB
imgRGBsmall=cv2.resize(imgRGB,(400,250))
plt.imshow(imgRGBsmall)

# %%
# 5. Melakukan Flipping

imgBalik=cv2.flip(imgRGBsmall,1)
plt.imshow(imgBalik)

# %%
imgBalik=cv2.flip(imgRGBsmall,1)

#tampilkan ukuran canvas yang lebih besar
fig=plt.figure(figsize=(10,10))
ax=fig.add_subplot(111)
ax.imshow(imgBalik)

# %%
# 6. Membuat bentuk Geometri 2D dari OpenCV. Diawali dengan pembuatan black image dengan tipe data int16.

black_img = np.zeros(shape=(512,512,3),dtype=np.int16)
plt.imshow(black_img)

# %%
#perhatikan koordinat titik2 pt1 dan pt2
cv.rectangle(black_img, pt1=(384,0), pt2=(510,150), color=(0,255,0), thickness=10)
plt.imshow(black_img)

# %%
cv.rectangle(black_img, pt1=(200,200), pt2=(300,300), color=(0,0,255), thickness=10)
plt.imshow(black_img)

# %%
cv.circle(black_img, center=(100,100), radius=50, color=(255,0,0), thickness=8)
plt.imshow(black_img)

# %%
cv.line(black_img, pt1=(0,0), pt2=(512,512), color=(255,255,255), thickness=5)
plt.imshow(black_img)
plt.show()

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img,text='Hello',org=(10,500),fontFace=font,fontScale=4,color=(255,255,0),thickness=2,lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
black_img2=np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_img2)

# %%
vertices = np.array([[100,300],[200,200],[400,300],[200,400]],dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts = vertices.reshape((-1,1,2))
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
cv.polylines(black_img2,[pts],isClosed=True,color=(255,0,0),thickness=5)
plt.imshow(black_img2)

# %% [markdown]
# # PERTANYAAN PRAKTIKUM D3
# 1. Apakah perbedaan gambar yang ditampilkan tanpa dan dengan matplotlib?
# - Tanpa matplotlib, gambar hanya tampil sebagai data mentah (array) tanpa sumbu koordinat. Dengan matplotlib, gambar tampil sebagai plot lengkap dengan sumbu X/Y, title, dan pengaturan warna (colormap)
#
#
# 2. Apakah perbedaan dan pengaruhnya pembuatan black image antara tipe data
# int16 dan int32?
# - int16 hanya menampung nilai hingga 32.767, sedangkan int32 hingga 2 miliar. Pengaruhnya: jika memakai int16 untuk gambar berwarna, nilai piksel mudah meluap (overflow) sehingga warna jadi salah. int32 lebih aman dan presisi
#
# 3. Apakah kegunaan “google.colab.patches import cv2_imshow” pada potongan
# kode berikut
# from google.colab.patches import cv2_imshow
# from skimage import io
# - cv2_imshow adalah pengganti cv2.imshow() untuk menampilkan gambar langsung di dalam notebook Colab, tanpa perlu membuka jendela terpisah
#
# 4. Apakah kegunaan “skimage import io” pada potongan kode soal nomor 3
# - skimage.io digunakan untuk membaca dan menulis file gambar (seperti io.imread()) yang mengubahnya menjadi array NumPy agar bisa diproses lebih lanjut

# %%
# Tugas praktikum D3
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow

# %%
# 1.

img = cv2.imread('Cuplikan layar 2026-09-04 184341.png')
plt.figure(figsize=(15, 10))
plt.imshow(img)
plt.show()
print("Ukuran asli pixel:", img.shape)
# Out:
# Ukuran asli pixel: (310, 497, 3)

# %%
# 2.
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# Red-Blue (R dan B aktif, G = 0)
red_blue = img_rgb.copy()
red_blue[:, :, 1] = 0
plt.imshow(red_blue)
plt.title("Red-Blue")
plt.show()

# Green-Blue (G dan B aktif, R = 0)
green_blue = img_rgb.copy()
green_blue[:, :, 0] = 0
plt.imshow(green_blue)
plt.title("Green-Blue")
plt.show()

# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

# 1. Cek dulu isi folder Drive
# !ls /content/drive/MyDrive/PCdVK/

# 2. Baca gambar dari Drive
img = cv2.imread("/content/drive/MyDrive/PCdVK/Cuplikan layar 2026-09-04 184341.png")

if img is not None:
    print("Gambar berhasil dibaca!")
else:
    print("Gambar tidak ditemukan!")
# Out:
# 'Cuplikan layar 2026-09-04 184341.png'
# Gambar berhasil dibaca!

# %%
# 3.

img_rgb_crop = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img_crop = img_rgb_crop[20:115, 25:120]
plt.imshow(img_crop)
plt.show()

# %%
# 4.

img_red_channel = img[:, :, 2]
img_red_crop = img_red_channel[5:30, :]
plt.imshow(img_red_crop, cmap='gray')
plt.show()

# %%
# 5 .

black_img = np.zeros(shape=(512, 512, 3), dtype=np.int16)

for i in range(5):
    x = np.random.randint(0, 450)
    y = np.random.randint(0, 450)
    w = np.random.randint(20, 100)
    h = np.random.randint(20, 100)
    color = tuple(np.random.randint(0, 255, 3).tolist())
    cv.rectangle(black_img, pt1=(x, y), pt2=(x+w, y+h), color=color, thickness=3)

plt.imshow(black_img)
plt.show()

# %%
# 6.

img_terbalik = cv.flip(img, 1)
plt.imshow(cv.cvtColor(img_terbalik, cv2.COLOR_BGR2RGB))
plt.show()

# %%
# 7 .

foto = cv2.imread("/content/drive/MyDrive/PCdVK/Cuplikan layar 2026-09-04 184341.png")
foto_rgb = cv2.cvtColor(foto, cv2.COLOR_BGR2RGB)

cv.rectangle(foto_rgb, pt1=(150, 100), pt2=(350, 350), color=(255, 0, 0), thickness=3)
cv.circle(foto_rgb, center=(250, 220), radius=80, color=(0, 255, 0), thickness=3)

plt.imshow(foto_rgb)
plt.show()

# %%
# 8.

citra = cv2.imread("/content/drive/MyDrive/PCdVK/Cuplikan layar 2026-09-04 184341.png")
citra_bgr = citra.copy()
h, w = citra_bgr.shape[:2]

cv.rectangle(citra_bgr, pt1=(0, h-50), pt2=(50, h), color=(0, 0, 255), thickness=3)

plt.imshow(cv.cvtColor(citra_bgr, cv2.COLOR_BGR2RGB))
plt.show()

# %%
# 9.

img_nomor8 = citra_bgr.copy()
font = cv.FONT_HERSHEY_SIMPLEX

cv.putText(img_nomor8, 'Lena', org=(50, 50), fontFace=font, fontScale=2, color=(255, 255, 255), thickness=3, lineType=cv.LINE_AA)

plt.imshow(cv.cvtColor(img_nomor8, cv2.COLOR_BGR2RGB))
plt.show()
